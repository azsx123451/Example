# %%
import re
import json
import requests
from bs4 import BeautifulSoup
i = 1
w = []
while i <= 6:
    d=["why","add","queue","comparison","pool","sshared-memory"]
    for h in d:
    
        url = "https://morvanzhou.github.io/tutorials/python-basic/multiprocessing/{j}-{d}".format(j = i,d=h)
        a = requests.get(url)
        soup = BeautifulSoup(a.text, 'html5lib')
        c = soup.find_all('p')

        w.extend(soup)  
        print(type(c))
        i+=1
        if i==i:
            break

print(w)
# Out:
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# ['html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"', <html lang="zh-CN en"><head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="多进程 Multiprocessing 和多线程 threading 类似, 他们都是在 python 中用来并行运算的. 不过既然有了 threading, 为什么 Python 还要出一个 multiprocessing 呢? 原因很简单, 就是用来弥补 threading 的一些劣势" name="description"/>
#   <meta content="莫烦,python,tutorial,machine learning,python, 基础, 多进程, multiprocessing" name="keywords"/>
#   <meta content="Mofan, Morvan,莫烦,周沫凡,周莫烦,莫烦" name="author"/>
#   <meta content="https://morvanzhou.github.io/static/img/course_cover/multiprocessing.jpg" name="thumbnail"/>
#   <title>什么是 Multiprocessing - 多进程 Multiprocessing | 莫烦Python</title>
#
# ...

# %%
import requests
import json
from bs4 import BeautifulSoup
import html5lib

url = "http://webtest.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=basic"
data = json.loads(r'''{
    "method": "search",
    "searchMethod": "true",
    "tenderUpdate": "",
    "searchTarget": "",
    "orgName": "",
    "orgId": "",
    "hid_1": "1",
    "tenderName": "",
    "tenderId": "",
    "tenderType": "tenderDeclaration",
    "tenderWay": "1,2,3,4,5,6,7,10,12",
    "tenderDateRadio": "on",
    "tenderStartDateStr": "107/07/25",
    "tenderEndDateStr": "107/07/31",
    "tenderStartDate": "107/07/31",
    "tenderEndDate": "107/07/31",
    "isSpdt": "N",
    "proctrgCate": "",
    "btnQuery": "查詢",
    "hadUpdated": ""
}''')
headers = json.loads(r'''{
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "Cache-Control": "max-age=0",
    "Connection": "keep-alive",
    "Content-Length": "383",
    "Content-Type": "application/x-www-form-urlencoded",
    "Cookie": "NSC_xfcuftu_qfstjtufodf=ffffffff09081f6445525d5f4f58455e445a4a423660; cookiesession1=5856138CAGGSFP8BHKMTKPO3AIGF5E94; JSESSIONID=0000m6TZgAvkfI9dz5g-YjDYlqC:14obonkfs",
    "Host": "webtest.pcc.gov.tw",
    "Origin": "http://webtest.pcc.gov.tw",
    "Referer": "http://webtest.pcc.gov.tw/tps/pss/tender.do?method=goSearch&searchMode=common&searchType=basic",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
}''')

resp = requests.post(url, data=data, headers=headers)
soup = BeautifulSoup(resp.text, 'html5lib')
c = soup.find_all('a')
c
# Out:
# [<a href="/pis/index.jsp" title="回到首頁">回到首頁</a>,
#  <a href="#goContent" id="goToContent" onblur="goToContentOnBlur();" onclick="goToContentOnKeyUp(event);" onfocus="goToContentOnFocus();" style="text-decoration:none; position:relative; top:5px; left:-950px; color:white; font-size:13px;">跳到主要內容區塊</a>,
#  <a class="ctopfont" href="/pis/index.jsp" style="position: relative; top: 5px; left: -900px" title="回到首頁">回首頁</a>,
#  <a accesskey="U" href="#top_area" name="top_area" title="press alt-u">:::</a>,
#  <a href="/tps/pss/tender.do?method=goNews" title="English">English</a>,
#  <a href="/pis/main/pis/client/pssa/sitemap.do" title="網站導覽">網站導覽</a>,
#  <a href="/pis/main/pis/client/pssa/mail_form.do" title="意見信箱">意見信箱</a>,
#  <a accesskey="L" href="#left_area" name="left_area" style="color: #999999; text-decoration: none;" title="press alt-l">:::</a>,
# ...
